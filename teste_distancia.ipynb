# %% [markdown]
# # Estudo de Caso

# %% [markdown]
# Realizando teste para verificar o calculo de distancia entre o usuario SUS e a unidade execuntate.

# %% [markdown]
# ## importação de bibliotecas e dados

# %%
#instalação de biblioteca (opcional)
import pip
pip.main(["install","pandas","folium","matplotlib","geopy","requests","urllib"])

# %%
#importação de biblioteca
import folium 
import warnings
import urllib.request
import json
import time
import requests
import geopy.distance
import pandas as pd
import matplotlib.pyplot as plt
import folium.plugins as plugins
from folium.plugins import HeatMap
from email import header
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
from numpy import dtype
from collections import defaultdict, OrderedDict

# %%
#configurar pacotes
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#importação de dados
df_original = pd.read_csv('../SISREG_Estudo_caso-AI_FALTAS_USUARIOS/dados/DADOS_SISREG_teste.csv', 
    dtype={'CNES_EXECUTANTE':'str','IBGE_USUARIO':'str','CEP_USUARIO':'str', 'CEP_UNID_EXECUTANTE':'str'}) 
df_cep = pd.read_csv('../SISREG_Estudo_caso-AI_FALTAS_USUARIOS/dados/TABELA_CEP_BR.txt', 
    dtype=str, sep="	", header=None)
df_cep.columns = ['CEP','UF','CIDADE','BAIRRO','LOGRADOURO']

# %% [markdown]
# ## Tratamento com os CEP's

# %%
#quantidade de CEP's importado
df_cep.shape
# Out:
# (849343, 5)

# %%
#criando um DataFrame somente os CEP's dos usuarios.
df_ceps_usuario = df_original['CEP_USUARIO']
df_ceps_usuario = pd.DataFrame(df_ceps_usuario)
df_ceps_usuario.drop_duplicates(inplace=True)
df_ceps_usuario.dropna(inplace=True)
df_ceps_usuario.head(5)
# Out:
#   CEP_USUARIO
# 0    89180000
# 1    58410080
# 2    89687000
# 3    89896000
# 4    89745000

# %%
#quantidade de CEP's localizado na base 

print("Cep's unicos de usuarios: ",df_ceps_usuario.count())
# Out:
# Cep's unicos de usuarios:  CEP_USUARIO    173
# dtype: int64

# %%
#localizando endereço do usuario com a base do CEP's BR
df_ceps_usuario = pd.merge(df_ceps_usuario, df_cep, left_on=['CEP_USUARIO'],right_on=['CEP'] , how='left')

# %%
#criando um endereço completo para realizar pesquisa de lat e log
df_ceps_usuario["END_COMPLETO"] = df_ceps_usuario['LOGRADOURO']+ " - " + df_ceps_usuario['CIDADE']+ " - " + df_ceps_usuario['UF']
df_ceps_usuario.dropna(inplace=True)
df_ceps_usuario.head(5)
# Out:
#    CEP_USUARIO       CEP  UF          CIDADE                     BAIRRO  \
# 1     58410080  58410080  PB  Campina Grande              Estação Velha
# 7     72855172  72855172  GO        Luziânia  Parque Industrial Mingone
# 12    72810520  72810520  GO        Luziânia   Setor Presidente Kennedy
# 14    72800040  72800040  GO        Luziânia                     Centro
# 15    72815120  72815120  GO        Luziânia                Setor Mandu
#
#                      LOGRADOURO  \
# 1   Rua João Caetano de Andrade
# 7             Quadra Quadra 172
# 12                   Rua Paraná
# 14     Travessa Nirson Carneiro
# 15                       Rua 31
#
#                                          END_COMPLETO
# 1   Rua João Caetano de Andrade - Campina Grande - PB
# 7                   Quadra Quadra 172 - Luziânia - GO
# 12                         Rua Paraná - Luziânia - GO
# 14           Travessa Nirson Carneiro - Luziânia - GO
# 15                             Rua 31 - Luziânia - GO

# %%
#localizando lat e log 
locator = Nominatim(user_agent='localizacao')
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)
df_ceps_usuario["GEOLOCALIZADO"] = df_ceps_usuario["END_COMPLETO"].apply(geocode)
df_ceps_usuario.head(10)
# Out:
#    CEP_USUARIO       CEP  UF          CIDADE                        BAIRRO  \
# 1     58410080  58410080  PB  Campina Grande                 Estação Velha
# 7     72855172  72855172  GO        Luziânia     Parque Industrial Mingone
# 12    72810520  72810520  GO        Luziânia      Setor Presidente Kennedy
# 14    72800040  72800040  GO        Luziânia                        Centro
# 15    72815120  72815120  GO        Luziânia                   Setor Mandu
# 16    72803360  72803360  GO        Luziânia                   Setor Leste
# 17    78552349  78552349  MT           Sinop          Jardim das Oliveiras
# 18    06815640  06815640  SP  Embu das Artes  Conjunto Habitacional Embu N
# 20    06843140  06843140  SP  Embu das Artes                Vila Marajoara
# 22    58400090  58400090  PB  Campina Grande                        Centro
#
#                      LOGRADOURO  \
# 1   Rua João Caetano de Andrade
# 7             Quadra Quadra 172
# 12                   Rua Paraná
# 14     Travessa Nirson Carneiro
# 15                       Rua 31
# 16     Rua Antônio Vieira Filho
# 17             Rua das Dombéias
# 18               Rua Ana Moysés
# 20                 Rua Paiaguas
# 22           Rua Venâncio Neiva
#
#                                          END_COMPLETO  \
# 1   Rua João Caetano de Andrade - Campina Grande - PB
# 7                   Quadra Quadra 172 - Luziânia - GO
# 12                         Rua Paraná - Luziânia - GO
# 14           Travessa Nirson Carneiro - Luziânia - GO
# 15                             Rua 31 - Luziânia - GO
# 16           Rua Antônio Vieira Filho - Luziânia - GO
# 17                      Rua das Dombéias - Sinop - MT
# 18               Rua Ana Moysés - Embu das Artes - SP
# 20                 Rua Paiaguas - Embu das Artes - SP
# 22           Rua Venâncio Neiva - Campina Grande - PB
#
#                                         GEOLOCALIZADO
# 1                                                None
# 7   (Quadra 12, Valparaíso de Goiás, Região Geográ...
# 12  (Rua Paraná, São Caetano, Luziânia, Região Geo...
# 14                                               None
# 15  (Rua 31, Vila Guará, Luziânia, Região Geográfi...
# 16                                               None
# 17                                               None
# 18                                               None
# 20  (Rua Paiaguás, Vila Santa Clara, Jardim Pinhei...
# 22  (Rua Venâncio Neiva, Centro, Campina Grande, R...

# %%
#verificar LOCALIZAÇÃO lat e log não localizada (limpeza)
df_ceps_usuario.dropna(inplace=True)

# %%
#colocando a LATITUDE e LONGITUDE na tabela
df_ceps_usuario['LATITUDE_USUARIO'] = df_ceps_usuario['GEOLOCALIZADO'].apply(lambda loc: loc.latitude)
df_ceps_usuario['LONGITUDE_USUARIO'] = df_ceps_usuario['GEOLOCALIZADO'].apply(lambda loc: loc.longitude)
df_ceps_usuario.drop('END_COMPLETO', axis=1, inplace=True)
df_ceps_usuario.drop('GEOLOCALIZADO', axis=1, inplace=True)
df_ceps_usuario.head(10)
# Out:
#    CEP_USUARIO       CEP  UF          CIDADE                     BAIRRO  \
# 7     72855172  72855172  GO        Luziânia  Parque Industrial Mingone
# 12    72810520  72810520  GO        Luziânia   Setor Presidente Kennedy
# 15    72815120  72815120  GO        Luziânia                Setor Mandu
# 20    06843140  06843140  SP  Embu das Artes             Vila Marajoara
# 22    58400090  58400090  PB  Campina Grande                     Centro
# 23    72837090  72837090  GO        Luziânia         Parque Alvorada II
# 27    06816220  06816220  SP  Embu das Artes               Parque Luíza
# 31    72815610  72815610  GO        Luziânia                  Parque JK
# 32    06803040  06803040  SP  Embu das Artes                     Centro
# 33    58415270  58415270  PB  Campina Grande          Jardim Paulistano
#
#                  LOGRADOURO  LATITUDE_USUARIO  LONGITUDE_USUARIO
# 7         Quadra Quadra 172        -16.086994         -47.983412
# 12               Rua Paraná        -16.261027         -47.942692
# 15                   Rua 31        -16.228359         -47.911296
# 20             Rua Paiaguas        -23.680583         -46.865803
# 22       Rua Venâncio Neiva         -7.219468         -35.883776
# 23                   Rua 75        -16.156912         -47.954593
# 27        Rua Campo Florido        -23.646898         -46.818152
# 31                   Rua 19        -16.279330         -47.859893
# 32          Rua do Virgílio        -23.651426         -46.848613
# 33  Rua Doutor Edésio Silva         -7.249646         -35.891586

# %%
#nomeação das colunas para usuarios
df_ceps_usuario.rename(columns={'CEP':'CEP_USUARIO', 'UF':'UF_USUARIO' , 'CIDADE':'CIDADE_USUARIO' , 'BAIRRO':'BAIRRO_USUARIO' ,'LOGRADOURO':'LOGRADOURO_USUARIO' })
# Out:
#     CEP_USUARIO CEP_USUARIO UF_USUARIO  CIDADE_USUARIO  \
# 7      72855172    72855172         GO        Luziânia
# 12     72810520    72810520         GO        Luziânia
# 15     72815120    72815120         GO        Luziânia
# 20     06843140    06843140         SP  Embu das Artes
# 22     58400090    58400090         PB  Campina Grande
# 23     72837090    72837090         GO        Luziânia
# 27     06816220    06816220         SP  Embu das Artes
# 31     72815610    72815610         GO        Luziânia
# 32     06803040    06803040         SP  Embu das Artes
# 33     58415270    58415270         PB  Campina Grande
# 35     78555022    78555022         MT           Sinop
# 38     76962176    76962176         RO          Cacoal
# 41     78556860    78556860         MT           Sinop
# 42     72855206    72855206         GO        Luziânia
# 43     72810150    72810150         GO        Luziânia
# 46     06816150    06816150         SP  Embu das Artes
# 47     72850595    72850595         GO        Luziânia
# 50     72805330    72805330         GO        Luziânia
# 54     78553558    78553558         MT           Sinop
# 55     72850660    72850660         GO        Luziânia
# 59     06816480    06816480         SP  Embu das Artes
# 60     06816100    06816100         SP  Embu das Artes
# 64     89021000    89021000         SC        Blumenau
# 72     72820150    72820150         GO        Luziânia
# 73     06814560    06814560         SP  Embu das Artes
# 75     72815710    72815710         GO        Luziânia
# 76     78557733    78557733         MT           Sinop
# 78     72855576    72855576         GO        Luziânia
# 79     66073220    66073220         PA           Belém
# 80     72836270    72836270         GO        Luziânia
# 81     06824170    06824170         SP  Embu das Artes
# 84     05754071    05754071         SP       São Paulo
# 91     72853028    72853028         GO        Luziânia
# 92     06824230    06824230         SP  Embu das Artes
# 94     06815040    06815040         SP  Embu das Artes
# 95     78550490    78550490         MT           Sinop
# 99     72805240    72805240         GO        Luziânia
# 100    72810600    72810600         GO        Luziânia
# 101    78552340    78552340         MT           Sinop
# 105    89801000    89801000         SC         Chapecó
# 106    06815110    06815110         SP  Embu das Artes
# 107    72804230    72804230         GO        Luziânia
# 108    72410307    72410307         DF        Brasília
# 114         -7.230878         -35.905235
# 116        -16.157767         -47.936472
# 117        -23.620402         -46.816603
# 122        -11.879523         -55.493844
# 123        -11.842716         -55.528204
# 124        -16.188611         -47.936312
# 125        -16.138980         -47.948330
# 126        -16.174508         -47.924198
# 128         -7.213300         -35.948969
# 135        -23.644073         -46.818628
# 139        -16.363527         -47.929619
# 142         -7.229325         -35.917476
# 144        -27.107005         -52.682170
# 146        -23.653574         -46.815139
# 148        -16.222849         -47.939139
# 149        -28.699988         -49.428980
# 150         -7.257689         -35.910645
# 153        -23.682805         -46.854743
# 156         -7.215383         -35.855596
# 157        -23.644814         -46.807419
# 165        -16.179284         -47.931948
# 166        -11.818532         -55.478375
# 167         -7.176637         -35.979719
# 171        -23.653574         -46.815139
# 172        -23.674961         -46.844585

# %%
#quantidade de CEP's localizado na base e tratado
print("Cep's unicos de usuarios: ",df_ceps_usuario.count())
# Out:
# Cep's unicos de usuarios:  CEP_USUARIO          70
# CEP                  70
# UF                   70
# CIDADE               70
# BAIRRO               70
# LOGRADOURO           70
# LATITUDE_USUARIO     70
# LONGITUDE_USUARIO    70
# dtype: int64

# %%
df_original_c = pd.merge(df_original, df_ceps_usuario, how="inner", on="CEP_USUARIO")
df_original_c.head()
# Out:
#    CNS_USUARIO  IDADE_USUARIO MUNICIPIO_USUARIO IBGE_USUARIO SEXO_USUARIO  \
# 0  125371X74X7             66          LUZIANIA       521250     FEMININO
# 1  14786XX69X7             61          LUZIANIA       521250     FEMININO
# 2  725379X74X7             44          LUZIANIA       521250     FEMININO
# 3  1521X5X63X7             14          LUZIANIA       521250     FEMININO
# 4  172416X96X7              1              EMBU       351500     FEMININO
#
#   RACA_COR_USUARIO CEP_USUARIO  \
# 0          AMARELA    72855172
# 1           BRANCA    72810520
# 2          AMARELA    72810520
# 3          AMARELA    72815120
# 4          AMARELA    06843140
#
#                                         DESLOCAMENTO CNES_EXECUTANTE  \
# 0  ATENDIDO NO MESMO MUNICIPIO DE RESIDENCIA DO U...         3857387
# 1  ATENDIDO NO MESMO MUNICIPIO DE RESIDENCIA DO U...         3857387
# 2  ATENDIDO NO MESMO MUNICIPIO DE RESIDENCIA DO U...         3857387
# 3  ATENDIDO NO MESMO MUNICIPIO DE RESIDENCIA DO U...         3857387
# 4  ATENDIDO NO MESMO MUNICIPIO DE RESIDENCIA DO U...         7805497
#
#   CEP_UNID_EXECUTANTE          ESPECIALIDADE  \
# 0            72800970  MÉDICO OFTALMOLOGISTA
# 1            72800970  MÉDICO OFTALMOLOGISTA
# 2            72800970  MÉDICO OFTALMOLOGISTA
# 3            72800970  MÉDICO OFTALMOLOGISTA
# 4            06803080  MÉDICO DERMATOLOGISTA
#
#                                            GRAVIDADE  DATA_ATEND  \
# 0  PRIORIDADE 1 - URGÊNCIA, ATENDIMENTO O MAIS RÁ...  2020-05-01
# 1  PRIORIDADE 1 - URGÊNCIA, ATENDIMENTO O MAIS RÁ...  2020-05-01
# 2  PRIORIDADE 1 - URGÊNCIA, ATENDIMENTO O MAIS RÁ...  2020-05-01
# 3  PRIORIDADE 1 - URGÊNCIA, ATENDIMENTO O MAIS RÁ...  2020-05-01
# 4                 PRIORIDADE 3 - ATENDIMENTO ELETIVO  2020-05-01
#
#    TEMPO_ESPERA  CONF_ATEND  quant       CEP  UF          CIDADE  \
# 0            77  CONFIRMADO      1  72855172  GO        Luziânia
# 1            53  CONFIRMADO      1  72810520  GO        Luziânia
# 2            70  CONFIRMADO      1  72810520  GO        Luziânia
# 3            77  CONFIRMADO      1  72815120  GO        Luziânia
# 4             4  CONFIRMADO      1  06843140  SP  Embu das Artes
#
#                       BAIRRO         LOGRADOURO  LATITUDE_USUARIO  \
# 0  Parque Industrial Mingone  Quadra Quadra 172        -16.086994
# 1   Setor Presidente Kennedy         Rua Paraná        -16.261027
# 2   Setor Presidente Kennedy         Rua Paraná        -16.261027
# 3                Setor Mandu             Rua 31        -16.228359
# 4             Vila Marajoara       Rua Paiaguas        -23.680583
#
#    LONGITUDE_USUARIO
# 0         -47.983412
# 1         -47.942692
# 2         -47.942692
# 3         -47.911296
# 4         -46.865803

# %% [markdown]
# ## Tratamento com os CNES

# %%
#criando um DataFrame somente os CEP's das unidades.
df_ceps_cnes = df_original_c['CEP_UNID_EXECUTANTE']
df_ceps_cnes = pd.DataFrame(df_ceps_cnes)
df_ceps_cnes.drop_duplicates(inplace=True)
df_ceps_cnes.dropna(inplace=True)
df_ceps_cnes.head(5)
# Out:
#    CEP_UNID_EXECUTANTE
# 0             72800970
# 4             06803080
# 5             58428016
# 11            58400290
# 12            78556144

# %%
#quantidade de CEP's localizado na base 
print("Cep's unicos de usuarios: ",df_ceps_cnes.count())
# Out:
# Cep's unicos de usuarios:  CEP_UNID_EXECUTANTE    13
# dtype: int64

# %%
#localizando endereço do usuario com a base do CEP's BR
df_ceps_cnes = pd.merge(df_ceps_cnes, df_cep, left_on=['CEP_UNID_EXECUTANTE'],right_on=['CEP'] , how='left')

# %%
#criando um endereço completo para realizar pesquisa de lat e log
df_ceps_cnes["END_COMPLETO"] = df_ceps_cnes['LOGRADOURO']+ " - " + df_ceps_cnes['CIDADE']+ " - " + df_ceps_cnes['UF']
df_ceps_cnes.dropna(inplace=True)
df_ceps_cnes.head(5)
# Out:
#   CEP_UNID_EXECUTANTE       CEP  UF          CIDADE          BAIRRO  \
# 1            06803080  06803080  SP  Embu das Artes     Vila Carmem
# 2            58428016  58428016  PB  Campina Grande      Centenário
# 3            58400290  58400290  PB  Campina Grande          Centro
# 4            78556144  78556144  MT           Sinop  Jardim Paraíso
# 5            76966202  76966202  RO          Cacoal        Eldorado
#
#                             LOGRADOURO  \
# 1           Rua Ghers Stenberg Isidoro
# 2                  Rua Delmiro Gouveia
# 3                    Rua Treze de Maio
# 4              Avenida dos Flamboyants
# 5  Avenida Rosilene Xavier Transpadini
#
#                                         END_COMPLETO
# 1   Rua Ghers Stenberg Isidoro - Embu das Artes - SP
# 2          Rua Delmiro Gouveia - Campina Grande - PB
# 3            Rua Treze de Maio - Campina Grande - PB
# 4               Avenida dos Flamboyants - Sinop - MT
# 5  Avenida Rosilene Xavier Transpadini - Cacoal - RO

# %%
#localizando lat e log 
locator = Nominatim(user_agent='localizacao')
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)
df_ceps_cnes["GEOLOCALIZADO"] = df_ceps_cnes["END_COMPLETO"].apply(geocode)
df_ceps_cnes.head(10)
# Out:
#    CEP_UNID_EXECUTANTE       CEP  UF          CIDADE           BAIRRO  \
# 1             06803080  06803080  SP  Embu das Artes      Vila Carmem
# 2             58428016  58428016  PB  Campina Grande       Centenário
# 3             58400290  58400290  PB  Campina Grande           Centro
# 4             78556144  78556144  MT           Sinop   Jardim Paraíso
# 5             76966202  76966202  RO          Cacoal         Eldorado
# 7             66080472  66080472  PA           Belém            Marco
# 10            78550110  78550110  MT           Sinop  Setor Comercial
#
#                              LOGRADOURO  \
# 1            Rua Ghers Stenberg Isidoro
# 2                   Rua Delmiro Gouveia
# 3                     Rua Treze de Maio
# 4               Avenida dos Flamboyants
# 5   Avenida Rosilene Xavier Transpadini
# 7               Travessa Mariz e Barros
# 10                 Avenida das Embaúbas
#
#                                          END_COMPLETO  \
# 1    Rua Ghers Stenberg Isidoro - Embu das Artes - SP
# 2           Rua Delmiro Gouveia - Campina Grande - PB
# 3             Rua Treze de Maio - Campina Grande - PB
# 4                Avenida dos Flamboyants - Sinop - MT
# 5   Avenida Rosilene Xavier Transpadini - Cacoal - RO
# 7                Travessa Mariz e Barros - Belém - PA
# 10                  Avenida das Embaúbas - Sinop - MT
#
#                                         GEOLOCALIZADO
# 1                                                None
# 2   (Rua Delmiro Gouveia, São José, Campina Grande...
# 3   (Rua Treze de Maio, Centro, Campina Grande, Re...
# 4   (Avenida dos Flamboyants, Sinop, Região Geográ...
# 5                                                None
# 7   (Travessa Mariz e Barros, Marco, Guamá, Belém,...
# 10  (Avenida das Embaubas, Sinop, Região Geográfic...

# %%
#verificar LOCALIZAÇÃO lat e log não localizada (limpeza)
df_ceps_cnes.dropna(inplace=True)

# %%
#nomeação das colunas para unidades
df_ceps_cnes.rename(columns={'CEP':'CEP_CNES', 'UF':'UF_CNES' , 'CIDADE':'CIDADE_CNES' , 'BAIRRO':'BAIRRO_CNES' ,'LOGRADOURO':'LOGRADOURO_CNES' })
# Out:
#    CEP_UNID_EXECUTANTE  CEP_CNES UF_CNES     CIDADE_CNES      BAIRRO_CNES  \
# 2             58428016  58428016      PB  Campina Grande       Centenário
# 3             58400290  58400290      PB  Campina Grande           Centro
# 4             78556144  78556144      MT           Sinop   Jardim Paraíso
# 7             66080472  66080472      PA           Belém            Marco
# 10            78550110  78550110      MT           Sinop  Setor Comercial
#
#             LOGRADOURO_CNES                               END_COMPLETO  \
# 2       Rua Delmiro Gouveia  Rua Delmiro Gouveia - Campina Grande - PB
# 3         Rua Treze de Maio    Rua Treze de Maio - Campina Grande - PB
# 4   Avenida dos Flamboyants       Avenida dos Flamboyants - Sinop - MT
# 7   Travessa Mariz e Barros       Travessa Mariz e Barros - Belém - PA
# 10     Avenida das Embaúbas          Avenida das Embaúbas - Sinop - MT
#
#                                         GEOLOCALIZADO
# 2   (Rua Delmiro Gouveia, São José, Campina Grande...
# 3   (Rua Treze de Maio, Centro, Campina Grande, Re...
# 4   (Avenida dos Flamboyants, Sinop, Região Geográ...
# 7   (Travessa Mariz e Barros, Marco, Guamá, Belém,...
# 10  (Avenida das Embaubas, Sinop, Região Geográfic...

# %%
#colocando a LATITUDE e LONGITUDE na tabela
df_ceps_cnes['LATITUDE_UNIDADE'] = df_ceps_cnes['GEOLOCALIZADO'].apply(lambda loc: loc.latitude)
df_ceps_cnes['LONGITUDE_UNIDADE'] = df_ceps_cnes['GEOLOCALIZADO'].apply(lambda loc: loc.longitude)
df_ceps_cnes.drop('END_COMPLETO', axis=1, inplace=True)
df_ceps_cnes.drop('GEOLOCALIZADO', axis=1, inplace=True)
df_ceps_cnes.head(10)
# Out:
#    CEP_UNID_EXECUTANTE       CEP  UF          CIDADE           BAIRRO  \
# 2             58428016  58428016  PB  Campina Grande       Centenário
# 3             58400290  58400290  PB  Campina Grande           Centro
# 4             78556144  78556144  MT           Sinop   Jardim Paraíso
# 7             66080472  66080472  PA           Belém            Marco
# 10            78550110  78550110  MT           Sinop  Setor Comercial
#
#                  LOGRADOURO  LATITUDE_UNIDADE  LONGITUDE_UNIDADE
# 2       Rua Delmiro Gouveia         -7.227300         -35.897340
# 3         Rua Treze de Maio         -7.221196         -35.885950
# 4   Avenida dos Flamboyants        -11.873144         -55.499869
# 7   Travessa Mariz e Barros         -1.444061         -48.451163
# 10     Avenida das Embaúbas        -11.859557         -55.499867

# %%
#quantidade de CEP's localizado na base e tratado
print("Cep's unicos de usuarios: ",df_ceps_cnes.count())
# Out:
# Cep's unicos de usuarios:  CEP_UNID_EXECUTANTE    5
# CEP                    5
# UF                     5
# CIDADE                 5
# BAIRRO                 5
# LOGRADOURO             5
# LATITUDE_UNIDADE       5
# LONGITUDE_UNIDADE      5
# dtype: int64

# %%
df_original_cc = pd.merge(df_original_c, df_ceps_cnes, how="inner", on="CEP_UNID_EXECUTANTE")
df_original_cc.head()
# Out:
#    CNS_USUARIO  IDADE_USUARIO MUNICIPIO_USUARIO IBGE_USUARIO SEXO_USUARIO  \
# 0  176541XX5X7             33    CAMPINA GRANDE       250400     FEMININO
# 1  76455XX18X7             55    CAMPINA GRANDE       250400     FEMININO
# 2  6X568XXX4X7             52    CAMPINA GRANDE       250400    MASCULINO
# 3  957974X12X7             62    CAMPINA GRANDE       250400     FEMININO
# 4  9X34X9XXXX7              3    CAMPINA GRANDE       250400    MASCULINO
#
#   RACA_COR_USUARIO CEP_USUARIO  \
# 0           BRANCA    58400090
# 1       INDEFENIDA    58400090
# 2          AMARELA    58410387
# 3          AMARELA    58430118
# 4          AMARELA    58417763
#
#                                         DESLOCAMENTO CNES_EXECUTANTE  \
# 0  ATENDIDO NO MESMO MUNICIPIO DE RESIDENCIA DO U...         2362848
# 1  ATENDIDO NO MESMO MUNICIPIO DE RESIDENCIA DO U...         2362848
# 2  ATENDIDO NO MESMO MUNICIPIO DE RESIDENCIA DO U...         2362848
# 3  ATENDIDO NO MESMO MUNICIPIO DE RESIDENCIA DO U...         2362848
# 4  ATENDIDO NO MESMO MUNICIPIO DE RESIDENCIA DO U...         2362848
#
#   CEP_UNID_EXECUTANTE  ESPECIALIDADE                           GRAVIDADE  \
# 0            58428016  FONOAUDIÓLOGO  PRIORIDADE 3 - ATENDIMENTO ELETIVO
# 1            58428016  FONOAUDIÓLOGO  PRIORIDADE 3 - ATENDIMENTO ELETIVO
# 2            58428016  FONOAUDIÓLOGO  PRIORIDADE 3 - ATENDIMENTO ELETIVO
# 3            58428016  FONOAUDIÓLOGO  PRIORIDADE 3 - ATENDIMENTO ELETIVO
# 4            58428016  FONOAUDIÓLOGO  PRIORIDADE 3 - ATENDIMENTO ELETIVO
#
#    DATA_ATEND  TEMPO_ESPERA  CONF_ATEND  quant     CEP_x UF_x        CIDADE_x  \
# 0  2020-05-01             0  CONFIRMADO      1  58400090   PB  Campina Grande
# 1  2020-05-01             0  CONFIRMADO      1  58400090   PB  Campina Grande
# 2  2020-05-01             0  CONFIRMADO      1  58410387   PB  Campina Grande
# 3  2020-05-01             0  CONFIRMADO      1  58430118   PB  Campina Grande
# 4  2020-05-01             0  CONFIRMADO      1  58417763   PB  Campina Grande
#
#             BAIRRO_x                 LOGRADOURO_x  LATITUDE_USUARIO  \
# 0             Centro           Rua Venâncio Neiva         -7.219468
# 1             Centro           Rua Venâncio Neiva         -7.219468
# 2             Catolé  Rua Gilson Marinho da Silva         -7.230878
# 3          Bodocongó    Rua Pedro Marcelino Diniz         -7.229325
# 4  Presidente Médici  Rua José Galdino dos Santos         -7.257689
#
#    LONGITUDE_USUARIO     CEP_y UF_y        CIDADE_y    BAIRRO_y  \
# 0         -35.883776  58428016   PB  Campina Grande  Centenário
# 1         -35.883776  58428016   PB  Campina Grande  Centenário
# 2         -35.905235  58428016   PB  Campina Grande  Centenário
# 3         -35.917476  58428016   PB  Campina Grande  Centenário
# 4         -35.910645  58428016   PB  Campina Grande  Centenário
#
#           LOGRADOURO_y  LATITUDE_UNIDADE  LONGITUDE_UNIDADE
# 0  Rua Delmiro Gouveia           -7.2273          -35.89734
# 1  Rua Delmiro Gouveia           -7.2273          -35.89734
# 2  Rua Delmiro Gouveia           -7.2273          -35.89734
# 3  Rua Delmiro Gouveia           -7.2273          -35.89734
# 4  Rua Delmiro Gouveia           -7.2273          -35.89734

# %% [markdown]
# ## Calculando distancia (usuario x unidade executante)

# %%
#calcular a distancia da unidade executante e USUARIO (LAT E LON)
for idx, row in df_original_cc.iterrows():
    coord_usuario = (row.LATITUDE_USUARIO, row.LONGITUDE_USUARIO)
    coord_unidadeEXE = (row.LATITUDE_UNIDADE, row.LONGITUDE_UNIDADE)

    df_original_cc.at[idx, "DISTANCIA_KM_USUARIO_UNIDADESOL"] = round(geopy.distance.distance(coord_usuario,coord_unidadeEXE).km, 2)

# %% [markdown]
# ## Analisando dados tratados

# %%
df_original_cc.head(5)
# Out:
#    CNS_USUARIO  IDADE_USUARIO MUNICIPIO_USUARIO IBGE_USUARIO SEXO_USUARIO  \
# 0  176541XX5X7             33    CAMPINA GRANDE       250400     FEMININO
# 1  76455XX18X7             55    CAMPINA GRANDE       250400     FEMININO
# 2  6X568XXX4X7             52    CAMPINA GRANDE       250400    MASCULINO
# 3  957974X12X7             62    CAMPINA GRANDE       250400     FEMININO
# 4  9X34X9XXXX7              3    CAMPINA GRANDE       250400    MASCULINO
#
#   RACA_COR_USUARIO CEP_USUARIO  \
# 0           BRANCA    58400090
# 1       INDEFENIDA    58400090
# 2          AMARELA    58410387
# 3          AMARELA    58430118
# 4          AMARELA    58417763
#
#                                         DESLOCAMENTO CNES_EXECUTANTE  \
# 0  ATENDIDO NO MESMO MUNICIPIO DE RESIDENCIA DO U...         2362848
# 1  ATENDIDO NO MESMO MUNICIPIO DE RESIDENCIA DO U...         2362848
# 2  ATENDIDO NO MESMO MUNICIPIO DE RESIDENCIA DO U...         2362848
# 3  ATENDIDO NO MESMO MUNICIPIO DE RESIDENCIA DO U...         2362848
# 4  ATENDIDO NO MESMO MUNICIPIO DE RESIDENCIA DO U...         2362848
#
#   CEP_UNID_EXECUTANTE  ESPECIALIDADE                           GRAVIDADE  \
# 0            58428016  FONOAUDIÓLOGO  PRIORIDADE 3 - ATENDIMENTO ELETIVO
# 1            58428016  FONOAUDIÓLOGO  PRIORIDADE 3 - ATENDIMENTO ELETIVO
# 2            58428016  FONOAUDIÓLOGO  PRIORIDADE 3 - ATENDIMENTO ELETIVO
# 3            58428016  FONOAUDIÓLOGO  PRIORIDADE 3 - ATENDIMENTO ELETIVO
# 4            58428016  FONOAUDIÓLOGO  PRIORIDADE 3 - ATENDIMENTO ELETIVO
#
#    DATA_ATEND  TEMPO_ESPERA  CONF_ATEND  quant     CEP_x UF_x        CIDADE_x  \
# 0  2020-05-01             0  CONFIRMADO      1  58400090   PB  Campina Grande
# 1  2020-05-01             0  CONFIRMADO      1  58400090   PB  Campina Grande
# 2  2020-05-01             0  CONFIRMADO      1  58410387   PB  Campina Grande
# 3  2020-05-01             0  CONFIRMADO      1  58430118   PB  Campina Grande
# 4  2020-05-01             0  CONFIRMADO      1  58417763   PB  Campina Grande
#
#             BAIRRO_x                 LOGRADOURO_x  LATITUDE_USUARIO  \
# 0             Centro           Rua Venâncio Neiva         -7.219468
# 1             Centro           Rua Venâncio Neiva         -7.219468
# 2             Catolé  Rua Gilson Marinho da Silva         -7.230878
# 3          Bodocongó    Rua Pedro Marcelino Diniz         -7.229325
# 4  Presidente Médici  Rua José Galdino dos Santos         -7.257689
#
#    LONGITUDE_USUARIO     CEP_y UF_y        CIDADE_y    BAIRRO_y  \
# 0         -35.883776  58428016   PB  Campina Grande  Centenário
# 1         -35.883776  58428016   PB  Campina Grande  Centenário
# 2         -35.905235  58428016   PB  Campina Grande  Centenário
# 3         -35.917476  58428016   PB  Campina Grande  Centenário
# 4         -35.910645  58428016   PB  Campina Grande  Centenário
#
#           LOGRADOURO_y  LATITUDE_UNIDADE  LONGITUDE_UNIDADE  \
# 0  Rua Delmiro Gouveia           -7.2273          -35.89734
# 1  Rua Delmiro Gouveia           -7.2273          -35.89734
# 2  Rua Delmiro Gouveia           -7.2273          -35.89734
# 3  Rua Delmiro Gouveia           -7.2273          -35.89734
# 4  Rua Delmiro Gouveia           -7.2273          -35.89734
#
#    DISTANCIA_KM_USUARIO_UNIDADESOL
# 0                             1.73
# 1                             1.73
# 2                             0.96
# 3                             2.24
# 4                             3.67

# %%
df_original_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19 entries, 0 to 18
# Data columns (total 31 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   CNS_USUARIO                      19 non-null     object
#  1   IDADE_USUARIO                    19 non-null     int64
#  2   MUNICIPIO_USUARIO                19 non-null     object
#  3   IBGE_USUARIO                     19 non-null     object
#  4   SEXO_USUARIO                     19 non-null     object
#  5   RACA_COR_USUARIO                 19 non-null     object
#  6   CEP_USUARIO                      19 non-null     object
#  7   DESLOCAMENTO                     19 non-null     object
#  8   CNES_EXECUTANTE                  19 non-null     object
#  9   CEP_UNID_EXECUTANTE              19 non-null     object
#  10  ESPECIALIDADE                    19 non-null     object
#  11  GRAVIDADE                        19 non-null     object
#  12  DATA_ATEND                       19 non-null     object
#  13  TEMPO_ESPERA                     19 non-null     int64
#  14  CONF_ATEND                       19 non-null     object
#  15  quant                            19 non-null     int64
#  16  CEP_x                            19 non-null     object
#  17  UF_x                             19 non-null     object
#  18  CIDADE_x                         19 non-null     object
#  19  BAIRRO_x                         19 non-null     object
#  20  LOGRADOURO_x                     19 non-null     object
#  21  LATITUDE_USUARIO                 19 non-null     float64
#  22  LONGITUDE_USUARIO                19 non-null     float64
#  23  CEP_y                            19 non-null     object
#  24  UF_y                             19 non-null     object
#  25  CIDADE_y                         19 non-null     object
#  26  BAIRRO_y                         19 non-null     object
#  27  LOGRADOURO_y                     19 non-null     object
#  28  LATITUDE_UNIDADE                 19 non-null     float64
#  29  LONGITUDE_UNIDADE                19 non-null     float64
#  30  DISTANCIA_KM_USUARIO_UNIDADESOL  19 non-null     float64
# dtypes: float64(5), int64(3), object(23)
# memory usage: 5.3+ KB

# %%
df_original_cc.count()
# Out:
# CNS_USUARIO                        19
# IDADE_USUARIO                      19
# MUNICIPIO_USUARIO                  19
# IBGE_USUARIO                       19
# SEXO_USUARIO                       19
# RACA_COR_USUARIO                   19
# CEP_USUARIO                        19
# DESLOCAMENTO                       19
# CNES_EXECUTANTE                    19
# CEP_UNID_EXECUTANTE                19
# ESPECIALIDADE                      19
# GRAVIDADE                          19
# DATA_ATEND                         19
# TEMPO_ESPERA                       19
# CONF_ATEND                         19
# quant                              19
# CEP_x                              19
# UF_x                               19
# CIDADE_x                           19
# BAIRRO_x                           19
# LOGRADOURO_x                       19
# LATITUDE_USUARIO                   19
# LONGITUDE_USUARIO                  19
# CEP_y                              19
# UF_y                               19
# CIDADE_y                           19
# BAIRRO_y                           19
# LOGRADOURO_y                       19
# LATITUDE_UNIDADE                   19
# LONGITUDE_UNIDADE                  19
# DISTANCIA_KM_USUARIO_UNIDADESOL    19
# dtype: int64

# %% [markdown]
# ## Gerando arquivo com os dados tratados

# %%
display(df_original_cc)
# Out:
#     CNS_USUARIO  IDADE_USUARIO MUNICIPIO_USUARIO IBGE_USUARIO SEXO_USUARIO  \
# 0   176541XX5X7             33    CAMPINA GRANDE       250400     FEMININO
# 1   76455XX18X7             55    CAMPINA GRANDE       250400     FEMININO
# 2   6X568XXX4X7             52    CAMPINA GRANDE       250400    MASCULINO
# 3   957974X12X7             62    CAMPINA GRANDE       250400     FEMININO
# 4   9X34X9XXXX7              3    CAMPINA GRANDE       250400    MASCULINO
# 5   X38354X76X7             33    CAMPINA GRANDE       250400     FEMININO
# 6   X94256X68X7             82    CAMPINA GRANDE       250400     FEMININO
# 7   2347X4X89X7             25    CAMPINA GRANDE       250400    MASCULINO
# 8   854322X67X7             11    CAMPINA GRANDE       250400    MASCULINO
# 9   252284XX5X7             18             SINOP       510790     FEMININO
# 10  289X89XX6X7             23             SINOP       510790     FEMININO
# 11  364297X4XX7             22             SINOP       510790     FEMININO
# 12  47793XXX6X7             26             SINOP       510790     FEMININO
# 13  559163X41X7             12             SINOP       510790     FEMININO
# 14  5X2X39XX4X7             25             SINOP       510790     FEMININO
# 15  814147X4XX7             18             SINOP       510790     FEMININO
# 16  X88614X32X7             26             SINOP       510790     FEMININO
# 17  498543X6XX7             64             BELEM       150140     FEMININO
# 18  792648X6XX7             61             SINOP       510790    MASCULINO
#
#    RACA_COR_USUARIO CEP_USUARIO  \
# 0            BRANCA    58400090
# 1        INDEFENIDA    58400090
# 2           AMARELA    58410387
# 3           AMARELA    58430118
# 4           AMARELA    58417763
# 5             PRETA    58406536
# 6             PARDA    58408072
# 7             PARDA    58415270
# 8           AMARELA    58436220
# 9           AMARELA    78555022
# 10           BRANCA    78556860
# 11          AMARELA    78553558
# 12          AMARELA    78557733
# 13            PARDA    78550490
# 14          AMARELA    78552340
# 15           BRANCA    78553869
# 16           BRANCA    78557421
# 17          AMARELA    66073220
# 18            PRETA    78557554
#
#                                          DESLOCAMENTO CNES_EXECUTANTE  \
# 0   ATENDIDO NO MESMO MUNICIPIO DE RESIDENCIA DO U...         
# 0   58428016   PB  Campina Grande       Centenário      Rua Delmiro Gouveia
# 1   58428016   PB  Campina Grande       Centenário      Rua Delmiro Gouveia
# 2   58428016   PB  Campina Grande       Centenário      Rua Delmiro Gouveia
# 3   58428016   PB  Campina Grande       Centenário      Rua Delmiro Gouveia
# 4   58428016   PB  Campina Grande       Centenário      Rua Delmiro Gouveia
# 5   58428016   PB  Campina Grande       Centenário      Rua Delmiro Gouveia
# 6   58428016   PB  Campina Grande       Centenário      Rua Delmiro Gouveia
# 7   58400290   PB  Campina Grande           Centro        Rua Treze de Maio
# 8   58400290   PB  Campina Grande           Centro        Rua Treze de Maio
# 9   78556144   MT           Sinop   Jardim Paraíso  Avenida dos Flamboyants
# 10  78556144   MT           Sinop   Jardim Paraíso  Avenida dos Flamboyants
# 11  78556144   MT           Sinop   Jardim Paraíso  Avenida dos Flamboyants
# 12  78556144   MT           Sinop   Jardim Paraíso  Avenida dos Flamboyants
# 13  78556144   MT           Sinop   Jardim Paraíso  Avenida dos Flamboyants
# 14  78556144   MT           Sinop   Jardim Paraíso  Avenida dos Flamboyants
# 15  78556144   MT           Sinop   Jardim Paraíso  Avenida dos Flamboyants
# 16  78556144   MT           Sinop   Jardim Paraíso  Avenida dos Flamboyants
# 17  66080472   PA           Belém            Marco  Travessa Mariz e Barros
# 18  78550110   MT           Sinop  Setor Comercial     Avenida das Embaúbas
#
#     LATITUDE_UNIDADE  LONGITUDE_UNIDADE  DISTANCIA_KM_USUARIO_UNIDADESOL
# 0          -7.227300         -35.897340                             1.73
# 1          -7.227300         -35.897340                             1.73
# 2          -7.227300         -35.897340                             0.96
# 3          -7.227300         -35.897340                             2.24
# 4          -7.227300         -35.897340                             3.67
# 5          -7.227300         -35.897340                             4.79
# 6          -7.227300         -35.897340                            10.69
# 7          -7.221196         -35.885950                             3.21
# 8          -7.221196         -35.885950                             7.01
# 9         -11.873144         -55.499869                             3.56
# 10        -11.873144         -55.499869                             2.27
# 11        -11.873144         -55.499869                             5.64
# 12        -11.873144         -55.499869                             2.27
# 13        -11.873144         -55.499869                             5.12
# 14        -11.873144         -55.499869                             5.20
# 15        -11.873144         -55.499869                             4.57
# 16        -11.873144         -55.499869                             6.48
# 17         -1.444061         -48.451163                             3.48
# 18        -11.859557         -55.499867                             2.30

# %%
geo_teste = df_original_cc.plot.scatter(y='LATITUDE_USUARIO', x='LONGITUDE_USUARIO', figsize=(10,8))

# %%
coordenadas= df_original_cc[['LATITUDE_USUARIO','LONGITUDE_USUARIO','ESPECIALIDADE']]

# %%
coordenadas = coordenadas.dropna()

# %%
baseMap = folium.Map(
    width= "100%", #800
    height=  "100%", #600
    location=[-15.77972,-47.92972],
    zoom_start=4
)

# %%
baseMap = baseMap.add_child(plugins.HeatMap(coordenadas))

# %%
baseMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_537a0422a256b9e9ddb77dbee3be9393 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_537a0422a256b9e9ddb77dbee3be9393&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_537a0422a256b9e9ddb77dbee3be9393 = L.map(
#                 &quot;map_537a0422a256b9e9ddb77dbee3be9393&quot;,
#                 {
#                     center: [-15.77972, -47.92972],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f447f76cadad3aaca589008d9766635 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_537a0422a256b9e9ddb77dbee3be9393);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
